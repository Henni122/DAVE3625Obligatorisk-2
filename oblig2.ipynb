# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Prediction passenger data for Ruter
#
# In this project, we will predict the avarage number of passangers on bus line 100 based on the data from
# Ruter-data.csv and the information given in ReadMe-Ruter-data.txt

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
df = pd.read_csv("Ruter-data.csv", sep=";", encoding="utf-8-sig")

df.head()
# Out:
# Linjenavn
# 100    465
# 110    362
# 390    247
# 31     220
# 360    189
# 350    181
# 380    180
# 440    172
# 400    172
# 420    162
# Name: count, dtype: int64

# %%
# We chose bus line 100
bus = df[df["Linjenavn"] == "100"].copy()

bus.head()
# Out:
#                               TurId        Dato  Fylke    Område     Kommune  \
# 38  10008-2020-08-09T11:24:00+02:00  09/08/2020  Viken   Nordøst  Lillestrøm
# 42  10004-2020-08-18T04:59:00+02:00  18/08/2020   Oslo   Nordøst        Alna
# 43  10009-2020-07-21T01:00:00+02:00  20/07/2020  Viken   Nordøst   Lørenskog
# 46  10004-2020-07-04T18:24:00+02:00  04/07/2020  Viken   Nordøst  Lillestrøm
# 51  10002-2020-07-22T08:30:00+02:00  22/07/2020   Oslo  Indre By  Gamle Oslo
#
#                             Holdeplass_Fra              Holdeplass_Til  \
# 38                                Sagdalen              Sagdalen skole
# 42            IKEA Furuset  (mot Kjelsrud)     Kjelsrud  (fra Furuset)
# 43                              Vittenberg             Strømsbergveien
# 46  UTGÅTT Lillestrøm bussterminal (P 19a)             Jonas Lies gate
# 51             Oslo bussterminal (Plf B10)  Oslo gate  (mot Galgeberg)
#
#    Linjetype Linjefylke Linjenavn  Linjeretning  \
# ...
