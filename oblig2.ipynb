# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Prediction passenger data for Ruter
#
# In this project, we will predict the avarage number of passangers on bus line 100 based on the data from
# Ruter-data.csv and the information given in ReadMe-Ruter-data.txt

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
df = pd.read_csv("Ruter-data.csv", sep=";", encoding="utf-8-sig")

# We chose bus line 100

df = df[df["Linjenavn"] == "100"]

df["Dato"] = pd.to_datetime(df["Dato"], dayfirst=True)

# %%
# Converting the date from an object to a number
# Reason: The computer does not understand the date in a text format like "01.09.2022"
# We have to change it to a numeric value like 01092022

df["year"] = df["Dato"].dt.year
df["month"] = df["Dato"].dt.month
df["day"] = df["Dato"].dt.day
df["weekday"] = df["Dato"].dt.weekday

# %%
# Here we create the input and output

x = df[["year", "month", "day", "weekday"]]
y = df["Passasjerer_Ombord"]

# X is the information the model will recieve
# Y is what the model is trying to predict

# %%
split = int()
